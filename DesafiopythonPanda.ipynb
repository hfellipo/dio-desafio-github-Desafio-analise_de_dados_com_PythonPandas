# %% [markdown]
# <a href="https://colab.research.google.com/github/hfellipo/dio-desafio-github-Desafio-analise_de_dados_com_PythonPandas/blob/main/DesafiopythonPanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("Solarize_Light2")

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/caso_full.csv", error_bad_lines=False )
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df.rename(columns={"city":"Cidade","estimated_population":"Populacao_estimada", "last_available_confirmed_per_100k_inhabitants":"Confirmados_100k_habitantes","place_type":"Cidade_ou_Estado","state":"Estado"})
# Out:
#                Cidade  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          Populacao_estimada  estimated_population_2019  is_last  is_repeated  \
# ...

# %%
df.isnull().sum()
# Out:
# city                                             20119
# city_ibge_code                                   13646
# date                                                 0
# epidemiological_week                                 0
# estimated_population                             13646
# estimated_population_2019                        13646
# is_last                                              0
# is_repeated                                          0
# last_available_confirmed                             0
# last_available_confirmed_per_100k_inhabitants    29166
# last_available_date                                  0
# last_available_death_rate                            0
# last_available_deaths                                0
# order_for_place                                      0
# place_type                                           0
# state                                                0
# new_confirmed                                        0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# city                                             0
# city_ibge_code                                   0
# date                                             0
# epidemiological_week                             0
# estimated_population                             0
# estimated_population_2019                        0
# is_last                                          0
# is_repeated                                      0
# last_available_confirmed                         0
# last_available_confirmed_per_100k_inhabitants    0
# last_available_date                              0
# last_available_death_rate                        0
# last_available_deaths                            0
# order_for_place                                  0
# place_type                                       0
# state                                            0
# new_confirmed                                    0
# new_deaths                                       0
# dtype: int64

# %%
df.rename(columns={"city":"Cidade","estimated_population":"Populacao_estimada", "last_available_confirmed_per_100k_inhabitants":"Confirmados_100k_habitantes","place_type":"Cidade_ou_Estado","state":"Estado"})
# Out:
#                Cidade  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# 6          Rio Branco       1200401.0  2020-03-20                202012
# 8          Rio Branco       1200401.0  2020-03-21                202012
# ...               ...             ...         ...                   ...
# 3853642    Tocantínia       1721109.0  2022-03-27                202213
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
#
#          Populacao_estimada  estimated_population_2019  is_last  is_repeated  \
# ...

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
# 6  Rio Branco       1200401.0  2020-03-20                202012
# 8  Rio Branco       1200401.0  2020-03-21                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 2              413418.0                   407319.0    False        False
# 4              413418.0                   407319.0    False        False
# 6              413418.0                   407319.0    False        False
# 8              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df["state"].unique()
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
df["state"].nunique()
# Out:
# 27

# %%
df["state"].value_counts(ascending=True)
# Out:
# DF       751
# RR     10613
# AP     11323
# AC     15364
# RO     35883
# AM     43775
# SE     52141
# MS     53443
# ES     55021
# RJ     65883
# AL     70606
# TO     93187
# MT     95472
# PA    101298
# RN    115427
# PE    129965
# CE    130182
# MA    150565
# PI    151505
# PB    152521
# GO    164633
# SC    202565
# PR    270397
# BA    283717
# RS    333592
# SP    446696
# MG    567844
# Name: state, dtype: int64

# %%
df.groupby("state")["city"].value_counts()
# Out:
# state  city
# AC     Rio Branco                   741
#        Acrelândia                   729
#        Porto Acre                   729
#        Plácido de Castro            721
#        Bujari                       719
#                                    ...
# TO     Lavandeira                   612
#        Porto Alegre do Tocantins    612
#        São Félix do Tocantins       612
#        Combinado                    611
#        Mateiros                     604
# Name: city, Length: 5570, dtype: int64

# %%
df["state"].value_counts().plot.bar(title="Numero de dados avaliados por estado");

# %%
df.groupby("state")["new_confirmed"].sum()
# Out:
# state
# AC      88061
# AL     293958
# AM     432593
# AP     125662
# BA    1248570
# CE     924635
# DF     597871
# ES     583626
# GO     934927
# MA     353311
# MG    2112518
# MS     366354
# MT     717742
# PA     733133
# PB     430617
# PE     628141
# PI     367533
# PR    1541987
# RJ    1289648
# RN     485469
# RO     265886
# RR     124558
# RS    2256435
# SC    1569638
# SE     278817
# SP    4444570
# TO     234134
# Name: new_confirmed, dtype: int64

# %%
df.groupby("state")["new_confirmed"].sum().plot.hist(title="Novos casos de COVID");
plt.xlabel("Estados")
plt.ylabel("Novos casos (N)");
